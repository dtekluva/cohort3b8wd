# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7dd3504c366f> in <module>
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\users\hp\appdata\local\programs\python\python37-32\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/hp/Desktop/cohort3b8wd/assignments/application_data.csv")

# %%
data
# Out:
#     customerID        loanId appilcationDate  LoanNumber  LoanAmount  \
# 0    839247458  302953235622      2018-12-21           1      7500.0
# 1    217540860  302960101337      2018-12-23           1      7500.0
# 2    522238092  303016988846      2019-01-08           1      7500.0
# 3    096754469  302999605504      2019-01-04           1      7500.0
# 4    410354345  302951945878      2018-12-21           1      7500.0
# ..         ...           ...             ...         ...         ...
# 995  964510149     302636726      2018-01-15           2      7500.0
# 996  251997198     302772445      2018-02-13           1      7500.0
# 997  899011279     302585439      2018-01-03           3      7500.0
# 998  648637210  302788322114      2018-11-19           1      7500.0
# 999  464788691     302683579      2018-01-24           1      7500.0
#
#      InterestRate  TermDays repaymentDueDate repaymentPaidDate
# 0            30.0        30       2019-01-20        2019-01-16
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data["loanId"]
# Out:
# 0      302953235622
# 1      302960101337
# 2      303016988846
# 3      302999605504
# 4      302951945878
#            ...
# 995       302636726
# 996       302772445
# 997       302585439
# 998    302788322114
# 999       302683579
# Name: loanId, Length: 1000, dtype: object

# %%
type(data["loanId"])
# Out:
# pandas.core.series.Series

# %%
data.iloc[995]
# Out:
# customerID            964510149
# loanId                302636726
# appilcationDate      2018-01-15
# LoanNumber                    2
# LoanAmount               7500.0
# InterestRate               30.0
# TermDays                     30
# repaymentDueDate     2018-02-14
# repaymentPaidDate    2018-01-20
# Name: 995, dtype: object

# %%
type(data.iloc[995])
# Out:
# pandas.core.series.Series

# %%
data.head()
# Out:
#   customerID        loanId appilcationDate  LoanNumber  LoanAmount  \
# 0  839247458  302953235622      2018-12-21           1      7500.0
# 1  217540860  302960101337      2018-12-23           1      7500.0
# 2  522238092  303016988846      2019-01-08           1      7500.0
# 3  096754469  302999605504      2019-01-04           1      7500.0
# 4  410354345  302951945878      2018-12-21           1      7500.0
#
#    InterestRate  TermDays repaymentDueDate repaymentPaidDate
# 0          30.0        30       2019-01-20        2019-01-16
# 1          30.0        30       2019-01-22        2018-12-29
# 2          30.0        30       2019-02-07        2019-01-08
# 3          30.0        30       2019-02-03        2019-01-08
# 4          30.0        30       2019-01-20        2019-01-17

# %%
data.tail()
# Out:
#     customerID        loanId appilcationDate  LoanNumber  LoanAmount  \
# 995  964510149     302636726      2018-01-15           2      7500.0
# 996  251997198     302772445      2018-02-13           1      7500.0
# 997  899011279     302585439      2018-01-03           3      7500.0
# 998  648637210  302788322114      2018-11-19           1      7500.0
# 999  464788691     302683579      2018-01-24           1      7500.0
#
#      InterestRate  TermDays repaymentDueDate repaymentPaidDate
# 995          30.0        30       2018-02-14        2018-01-20
# 996          30.0        30       2018-03-15        2018-03-14
# 997          30.0        30       2018-02-02        2018-10-12
# 998          30.0        30       2018-12-19        2018-12-17
# 999          30.0        30       2018-02-24        2018-02-11

# %%
data.head(15)
# Out:
#    customerID        loanId appilcationDate  LoanNumber  LoanAmount  \
# 0   839247458  302953235622      2018-12-21           1      7500.0
# 1   217540860  302960101337      2018-12-23           1      7500.0
# 2   522238092  303016988846      2019-01-08           1      7500.0
# 3   096754469  302999605504      2019-01-04           1      7500.0
# 4   410354345  302951945878      2018-12-21           1      7500.0
# 5   027610141  302955854172      2018-12-22           6     45000.0
# 6   390748423  302941689535      2018-12-19           4     90000.0
# 7   642947351  302945727970      2018-12-19           3     45000.0
# 8   227382168  302953081988      2018-12-21           4     45000.0
# 9   380684555  302997991362      2019-01-03           4     30000.0
# 10  538656471  302906015723      2018-12-10           1     13500.0
# 11  067501201  302955909012      2018-12-22           4     19000.0
# 12  779403451  302941503245      2018-12-19           4     59500.0
# ...

# %%
data.iloc[12:25]
# Out:
#    customerID        loanId appilcationDate  LoanNumber  LoanAmount  \
# 12  779403451  302941503245      2018-12-19           4     59500.0
# 13  706745423  302942096687      2018-12-19           1     32000.0
# 14  175032099  302948765318      2018-12-20           1      8000.0
# 15  756846529  302943137882      2018-12-19           7     16000.0
# 16  910833430  302985391002      2018-12-31           1     40500.0
# 17  789366247  302966696659      2018-12-25           7      9500.0
# 18  946771596  302919159103      2018-12-12           1     11000.0
# 19  363467351  302977645174      2018-12-28           1     11000.0
# 20  380721416  302935257840      2018-12-17           2     11000.0
# 21  476331961  302987067485      2018-12-31           1     11000.0
# 22  098589528  302933833928      2018-12-16           1     11000.0
# 23  063431769  302918179987      2018-12-12           1     11000.0
# 24  021449557  302982821720      2018-12-30           1     11000.0
#
# ...

# %% [markdown]
# statistical Information

# %%
data.describe()
# Out:
#         LoanNumber     LoanAmount  InterestRate    TermDays
# count  1000.000000    1000.000000   1000.000000  1000.00000
# mean      2.691000   13828.080000     23.061700    42.07500
# std       2.789139   19362.887991      8.415945    34.79339
# min       1.000000      80.000000      5.000000    15.00000
# 25%       1.000000    7500.000000     15.000000    30.00000
# 50%       2.000000    7500.000000     30.000000    30.00000
# 75%       3.000000   11000.000000     30.000000    45.00000
# max      26.000000  166000.000000     36.000000   180.00000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customerID         1000 non-null   object
#  1   loanId             1000 non-null   object
#  2   appilcationDate    1000 non-null   object
#  3   LoanNumber         1000 non-null   int64
#  4   LoanAmount         1000 non-null   float64
#  5   InterestRate       1000 non-null   float64
#  6   TermDays           1000 non-null   int64
#  7   repaymentDueDate   1000 non-null   object
#  8   repaymentPaidDate  1000 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 50.8+ KB

# %%
data.describe(include = ["O"])
# Out:
#        customerID        loanId appilcationDate repaymentDueDate  \
# count        1000          1000            1000             1000
# unique        985          1000             254              302
# top     686128144  302492546329      2018-12-19       2019-01-26
# freq            4             1              47               18
#
#        repaymentPaidDate
# count               1000
# unique               263
# top           2019-01-16
# freq                  45

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
new_data = pd.read_csv("C:/Users/hp/Desktop/cohort3b8wd/assignments/application_data.csv")

# %%
new_data
# Out:
#     customerID        loanId appilcationDate  LoanNumber  LoanAmount  \
# 0    839247458  302953235622      2018-12-21           1      7500.0
# 1    217540860  302960101337      2018-12-23           1      7500.0
# 2    522238092  303016988846      2019-01-08           1      7500.0
# 3    096754469  302999605504      2019-01-04           1      7500.0
# 4    410354345  302951945878      2018-12-21           1      7500.0
# ..         ...           ...             ...         ...         ...
# 995  964510149     302636726      2018-01-15           2      7500.0
# 996  251997198     302772445      2018-02-13           1      7500.0
# 997  899011279     302585439      2018-01-03           3      7500.0
# 998  648637210  302788322114      2018-11-19           1      7500.0
# 999  464788691     302683579      2018-01-24           1      7500.0
#
#      InterestRate  TermDays repaymentDueDate repaymentPaidDate
# 0            30.0        30       2019-01-20        2019-01-16
# ...

# %%
repayment_paid_to_datetime = pd.to_datetime(new_data["repaymentPaidDate"])

# %%
repayment_paid_to_datetime = new_data["repaymentPaidDate"].astype("datetime64")

# %%
new_data["repaymentPaidDate"] = repayment_paid_to_datetime #replaces the repaymentPaid with the converted version

# %%
r_due_date = pd.to_datetime(new_data["repaymentDueDate"])

# %%
r_due_date = new_data["repaymentDueDate"].astype("datetime64")

# %%
new_data["repaymentDueDate"] = r_due_date

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customerID         1000 non-null   object
#  1   loanId             1000 non-null   object
#  2   appilcationDate    1000 non-null   object
#  3   LoanNumber         1000 non-null   int64
#  4   LoanAmount         1000 non-null   float64
#  5   InterestRate       1000 non-null   float64
#  6   TermDays           1000 non-null   int64
#  7   repaymentDueDate   1000 non-null   datetime64[ns]
#  8   repaymentPaidDate  1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(2), object(3)
# memory usage: 58.7+ KB

# %%
new_data["dayPastDue"] = new_data["repaymentPaidDate"] - new_data["repaymentDueDate"]

# %%
new_data
# Out:
#     customerID        loanId appilcationDate  LoanNumber  LoanAmount  \
# 0    839247458  302953235622      2018-12-21           1      7500.0
# 1    217540860  302960101337      2018-12-23           1      7500.0
# 2    522238092  303016988846      2019-01-08           1      7500.0
# 3    096754469  302999605504      2019-01-04           1      7500.0
# 4    410354345  302951945878      2018-12-21           1      7500.0
# ..         ...           ...             ...         ...         ...
# 995  964510149     302636726      2018-01-15           2      7500.0
# 996  251997198     302772445      2018-02-13           1      7500.0
# 997  899011279     302585439      2018-01-03           3      7500.0
# 998  648637210  302788322114      2018-11-19           1      7500.0
# 999  464788691     302683579      2018-01-24           1      7500.0
#
#      InterestRate  TermDays repaymentDueDate repaymentPaidDate dayPastDue
# ...

# %%
new_data.columns
# Out:
# Index(['customerID', 'loanId', 'appilcationDate', 'LoanNumber', 'LoanAmount',
#        'InterestRate', 'TermDays', 'repaymentDueDate', 'repaymentPaidDate',
#        'dayPastDue'],
#       dtype='object')

# %%
new_data = new_data[['customerID', 'loanId', 'appilcationDate', 'LoanNumber', 'LoanAmount',
       'InterestRate', 'TermDays', 'dayPastDue', 'repaymentDueDate', 'repaymentPaidDate',
       ]]

# %%
new_data
# Out:
#     customerID        loanId appilcationDate  LoanNumber  LoanAmount  \
# 0    839247458  302953235622      2018-12-21           1      7500.0
# 1    217540860  302960101337      2018-12-23           1      7500.0
# 2    522238092  303016988846      2019-01-08           1      7500.0
# 3    096754469  302999605504      2019-01-04           1      7500.0
# 4    410354345  302951945878      2018-12-21           1      7500.0
# ..         ...           ...             ...         ...         ...
# 995  964510149     302636726      2018-01-15           2      7500.0
# 996  251997198     302772445      2018-02-13           1      7500.0
# 997  899011279     302585439      2018-01-03           3      7500.0
# 998  648637210  302788322114      2018-11-19           1      7500.0
# 999  464788691     302683579      2018-01-24           1      7500.0
#
#      InterestRate  TermDays dayPastDue repaymentDueDate repaymentPaidDate
# ...

# %%
new_data.info
# Out:
# <bound method DataFrame.info of     customerID        loanId appilcationDate  LoanNumber  LoanAmount  \
# 0    839247458  302953235622      2018-12-21           1      7500.0
# 1    217540860  302960101337      2018-12-23           1      7500.0
# 2    522238092  303016988846      2019-01-08           1      7500.0
# 3    096754469  302999605504      2019-01-04           1      7500.0
# 4    410354345  302951945878      2018-12-21           1      7500.0
# ..         ...           ...             ...         ...         ...
# 995  964510149     302636726      2018-01-15           2      7500.0
# 996  251997198     302772445      2018-02-13           1      7500.0
# 997  899011279     302585439      2018-01-03           3      7500.0
# 998  648637210  302788322114      2018-11-19           1      7500.0
# 999  464788691     302683579      2018-01-24           1      7500.0
#
#      InterestRate  TermDays dayPastDue repaymentDueDate repaymentPaidDate
# ...

# %%
new_data.repaymentDueDate.dt.month
# Out:
# 0       1
# 1       1
# 2       2
# 3       2
# 4       1
#        ..
# 995     2
# 996     3
# 997     2
# 998    12
# 999     2
# Name: repaymentDueDate, Length: 1000, dtype: int64

# %%
new_data.repaymentDueDate.dt.month_name()
# Out:
# 0       January
# 1       January
# 2      February
# 3      February
# 4       January
#          ...
# 995    February
# 996       March
# 997    February
# 998    December
# 999    February
# Name: repaymentDueDate, Length: 1000, dtype: object

# %%
new_data.repaymentDueDate.dt.day #ensure you have "dt" before the day, month or month_name
# Out:
# 0      20
# 1      22
# 2       7
# 3       3
# 4      20
#        ..
# 995    14
# 996    15
# 997     2
# 998    19
# 999    24
# Name: repaymentDueDate, Length: 1000, dtype: int64

# %%
new_data.repaymentDueDate.dt.day_name()
# Out:
# 0         Sunday
# 1        Tuesday
# 2       Thursday
# 3         Sunday
# 4         Sunday
#          ...
# 995    Wednesday
# 996     Thursday
# 997       Friday
# 998    Wednesday
# 999     Saturday
# Name: repaymentDueDate, Length: 1000, dtype: object
