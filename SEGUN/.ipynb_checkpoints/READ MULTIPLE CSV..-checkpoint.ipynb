# %%
import os
import glob
import pandas as pd

# %%
# %pwd
# Out:
# 'C:\\Users\\USER\\Desktop\\cohort3b8wd\\SEGUN'

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9E4E-BB87
#
#  Directory of C:\Users\USER\Desktop\cohort3b8wd\SEGUN
#
# 04/24/2021  08:02 PM    <DIR>          .
# 04/24/2021  08:02 PM    <DIR>          ..
# 04/24/2021  08:01 PM    <DIR>          .ipynb_checkpoints
# 03/29/2021  06:07 PM               927 __pmysql.py
# 03/29/2021  06:07 PM    <DIR>          __pycache__
# 03/20/2021  09:01 PM            65,248 application_data.csv
# 03/29/2021  06:07 PM               212 Ass_integer.py
# 03/29/2021  06:07 PM               276 Ass_name_last.py
# 04/14/2021  05:53 PM             9,242 built in functions and reference notebook.ipynb
# 03/29/2021  06:07 PM             2,849 classexercise.py
# 04/23/2021  06:50 PM    <DIR>          data
# 04/14/2021  05:19 PM             3,753 dict_ass.py
# 03/29/2021  06:07 PM               579 dictionarytodict.py
# 03/29/2021  06:07 PM               919 dictsplit.py
# 04/23/2021  09:13 PM            44,839 final.csv
# ...

# %%
os.chdir("/Users//USER//Desktop//cohort3b8wd//SEGUN")

# %%
# %pwd
# Out:
# 'C:\\Users\\USER\\Desktop\\cohort3b8wd\\SEGUN'

# %%
file_extension = (".csv")

# %%
all_file = [i for i in glob.glob(f'*{file_extension}')]

# %%
print(all_file)
# Out:
# ['application_data.csv', 'final.csv', 'modified.csv', 'pokemon_data.csv', 'time_series_covid19_confirmed_global.csv']

# %%
all_file[:]
# Out:
# ['application_data.csv',
#  'final.csv',
#  'modified.csv',
#  'pokemon_data.csv',
#  'time_series_covid19_confirmed_global.csv']

# %%
pd.read_csv("application_data.csv")
# Out:
#     customerID       loanId appilcationDate  LoanNumber  LoanAmount  \
# 0    839247458  3.02953E+11      12/21/2018           1        7500
# 1    217540860   3.0296E+11      12/23/2018           1        7500
# 2    522238092  3.03017E+11        1/8/2019           1        7500
# 3     96754469     3.03E+11        1/4/2019           1        7500
# 4    410354345  3.02952E+11      12/21/2018           1        7500
# ..         ...          ...             ...         ...         ...
# 995  964510149    302636726       1/15/2018           2        7500
# 996  251997198    302772445       2/13/2018           1        7500
# 997  899011279    302585439        1/3/2018           3        7500
# 998  648637210  3.02788E+11      11/19/2018           1        7500
# 999  464788691    302683579       1/24/2018           1        7500
#
#      InterestRate  TermDays repaymentDueDate repaymentPaidDate
# 0            30.0        30        1/20/2019         1/16/2019
# ...

# %%
[pd.read_csv(file)for file in all_file]
# Out:
# [    customerID       loanId appilcationDate  LoanNumber  LoanAmount  \
#  0    839247458  3.02953E+11      12/21/2018           1        7500
#  1    217540860   3.0296E+11      12/23/2018           1        7500
#  2    522238092  3.03017E+11        1/8/2019           1        7500
#  3     96754469     3.03E+11        1/4/2019           1        7500
#  4    410354345  3.02952E+11      12/21/2018           1        7500
#  ..         ...          ...             ...         ...         ...
#  995  964510149    302636726       1/15/2018           2        7500
#  996  251997198    302772445       2/13/2018           1        7500
#  997  899011279    302585439        1/3/2018           3        7500
#  998  648637210  3.02788E+11      11/19/2018           1        7500
#  999  464788691    302683579       1/24/2018           1        7500
#
#       InterestRate  TermDays repaymentDueDate repaymentPaidDate
#  0            30.0        30        1/20/2019         1/16/2019
# ...

# %%
[pd.read_csv(file,)for file in all_file][2]
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
merge_files = pd.concat([pd.read_csv(file,)for file in all_file])

# %%
merge_files
# Out:
#     customerID       loanId appilcationDate  LoanNumber  LoanAmount  \
# 0    839247458  3.02953E+11      12/21/2018         1.0      7500.0
# 1    217540860   3.0296E+11      12/23/2018         1.0      7500.0
# 2    522238092  3.03017E+11        1/8/2019         1.0      7500.0
# 3     96754469     3.03E+11        1/4/2019         1.0      7500.0
# 4    410354345  3.02952E+11      12/21/2018         1.0      7500.0
# ..         ...          ...             ...         ...         ...
# 269        NaN          NaN             NaN         NaN         NaN
# 270        NaN          NaN             NaN         NaN         NaN
# 271        NaN          NaN             NaN         NaN         NaN
# 272        NaN          NaN             NaN         NaN         NaN
# 273        NaN          NaN             NaN         NaN         NaN
#
#      InterestRate  TermDays repaymentDueDate repaymentPaidDate   #  ...  \
# 0            30.0      30.0        1/20/2019         1/16/2019 NaN  ...
# ...

# %%
merge_files.to_csv("test_csvs.csv")
