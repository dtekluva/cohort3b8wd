# %%
import pandas as pd
import numpy as np

# %%
mandates_n_creds = pd.read_csv("main_cleaned.csv-mandates-credits.csv")
loan_disk = pd.read_csv("all2 - Copy.csv")

# %%
# list(loan_disk.columns)
mandates_n_creds = mandates_n_creds.round(2)
loan_disk = loan_disk.round(2)

# %%
mandates_n_creds.drop(["Unnamed: 0"], axis = 1, inplace = True) # drop the unwanted column Unnamed: 0 from mandates

# %%
mandates_n_creds.columns = ['mandates_bank', ' CREDIT'] # rename mandates to mandates_bank

# %%
required_columns = ['loan_id',
                     'loan_principal_amount',
                     'loan_released_date',
                     'total_amount_due',
                     'balance_amount',
                     'due_date',
                     'total_paid',
                     'custom_field_4361',
                     'custom_field_4178',
                     'custom_field_5262',
                     'borrower_firstname',
                     'borrower_lastname',
                     'borrower_email',
                     'borrower_address',
                     ]
loan_disk_target = loan_disk[required_columns]

# %%
required_columns_customized = ['loan_id',
                                 'loan_principal_amount',
                                 'loan_released_date',
                                 'total_amount_due',
                                 'balance_amount',
                                 'due_date',
                                 'total_paid',
                                 'bvn',
                                 'account_no',
                                 'mandates_loandisk',
                                 'borrower_firstname',
                                 'borrower_lastname',
                                 'borrower_email',
                                 'borrower_address',
                                 ]

loan_disk_target.columns = required_columns_customized # change  certain column names in the fields

# %%
loan_disk_target = loan_disk_target.round(2)

# %%
pd.merge(
         left = loan_disk_target, 
         right=mandates_n_creds, 
         how="outer", 
         left_on="mandates_loandisk", 
         right_on="mandates_bank"
        )
# Out:
#          loan_id  loan_principal_amount loan_released_date  total_amount_due  \
# 0      1369069.0                40000.0         24/05/2020               NaN
# 1      1369070.0                40000.0         24/05/2020               NaN
# 2      1369071.0                30000.0         24/05/2020               NaN
# 3      1369072.0                30000.0         25/05/2020               NaN
# 4      1369073.0                10000.0         25/05/2020               NaN
# ...          ...                    ...                ...               ...
# 12503        NaN                    NaN                NaN               NaN
# 12504        NaN                    NaN                NaN               NaN
# 12505        NaN                    NaN                NaN               NaN
# 12506        NaN                    NaN                NaN               NaN
# 12507        NaN                    NaN                NaN               NaN
#
#        balance_amount    due_date  total_paid           bvn    account_no  \
# 0                0.00  31/05/2020    50000.00  2.215512e+10  5.857885e+07
# 1            20472.64  31/05/2020    29527.36  2.224831e+10  3.280263e+09
# 2                0.00  31/05/2020    37500.00  2.226486e+10  2.335742e+07
# 3                0.00  31/05/2020    37500.00  2.222417e+10  3.979875e+07
# 4                0.00  31/05/2020    12500.00  2.221116e+10  2.016782e+09
# ...               ...         ...         ...           ...           ...
# 12503             NaN         NaN         NaN           NaN           NaN
# 12504             NaN         NaN         NaN           NaN           NaN
# 12505             NaN         NaN         NaN           NaN           NaN
# 12506             NaN         NaN         NaN           NaN           NaN
# 12507             NaN         NaN         NaN           NaN           NaN
#
#        mandates_loandisk borrower_firstname borrower_lastname  \
# 0           1.803991e+11            DIAMOND         UDOIDIONG
# 1           1.403991e+11            KENNETH           ONWORDI
# 2           1.503991e+11          OLUWASEUN            FAYOMI
# 3           3.403993e+11            charles            udogwu
# 4           1.503993e+11              JAMES             ARONI
# ...                  ...                ...               ...
# 12503                NaN                NaN               NaN
# 12504                NaN                NaN               NaN
# 12505                NaN                NaN               NaN
# 12506                NaN                NaN               NaN
# 12507                NaN                NaN               NaN
#
#                  borrower_email  \
# 0       diamondray943@gmail.com
# 1          talk2sirnd@yahoo.com
# 2        fayomiooseun@yahoo.com
# 3                           NaN
# 4      jamesenders007@gmail.com
# ...                         ...
# 12503                       NaN
# 12504                       NaN
# 12505                       NaN
# 12506                       NaN
# 12507                       NaN
#
#                                         borrower_address  mandates_bank  \
# 0       NATIONAL OIL SPILL DETECTION AND RESPONSE AGENCY   1.803991e+11
# 1      FEDERAL MINISTRY OF INFORMATION & CULTURE - HQTRS   1.403991e+11
# 2                  MEDICAL AND DENTAL COUNCIL OF NIGERIA   1.503991e+11
# 3                    FEDERAL MEDICAL CENTRE, EBUTE METTA   3.403993e+11
# 4                    NATIONAL YOUTH SERVICE CORPS (NYSC)   1.503993e+11
# ...                                                  ...            ...
# 12503                                                NaN   3.404668e+11
# 12504                                                NaN   3.503991e+11
# 12505                                                NaN   3.504338e+11
# 12506                                                NaN   3.504404e+11
# 12507                                                NaN   3.504621e+11
#
#          CREDIT
# 0      50000.00
# 1      29378.93
# 2      37500.00
# 3      37500.00
# 4      12500.00
# ...         ...
# 12503  13300.00
# 12504      1.00
# 12505  11970.00
# 12506   6650.00
# 12507   7980.00
#
# [12508 rows x 16 columns]

# %%
merged = pd.merge(
                 left = loan_disk_target, 
                 right=mandates_n_creds, 
                 how="outer", 
                 left_on="mandates_loandisk", 
                 right_on="mandates_bank"
                 )

# %%
credit_difference = merged.total_paid - merged[" CREDIT"]
merged["credit_difference"] = credit_difference

# %%
merged
# Out:
#          loan_id  loan_principal_amount loan_released_date  total_amount_due  \
# 0      1369069.0                40000.0         24/05/2020               NaN
# 1      1369070.0                40000.0         24/05/2020               NaN
# 2      1369071.0                30000.0         24/05/2020               NaN
# 3      1369072.0                30000.0         25/05/2020               NaN
# 4      1369073.0                10000.0         25/05/2020               NaN
# ...          ...                    ...                ...               ...
# 12503        NaN                    NaN                NaN               NaN
# 12504        NaN                    NaN                NaN               NaN
# 12505        NaN                    NaN                NaN               NaN
# 12506        NaN                    NaN                NaN               NaN
# 12507        NaN                    NaN                NaN               NaN
#
#        balance_amount    due_date  total_paid           bvn    account_no  \
# 0                0.00  31/05/2020    50000.00  2.215512e+10  5.857885e+07
# 1            20472.64  31/05/2020    29527.36  2.224831e+10  3.280263e+09
# 2                0.00  31/05/2020    37500.00  2.226486e+10  2.335742e+07
# 3                0.00  31/05/2020    37500.00  2.222417e+10  3.979875e+07
# 4                0.00  31/05/2020    12500.00  2.221116e+10  2.016782e+09
# ...               ...         ...         ...           ...           ...
# 12503             NaN         NaN         NaN           NaN           NaN
# 12504             NaN         NaN         NaN           NaN           NaN
# 12505             NaN         NaN         NaN           NaN           NaN
# 12506             NaN         NaN         NaN           NaN           NaN
# 12507             NaN         NaN         NaN           NaN           NaN
#
#        mandates_loandisk borrower_firstname borrower_lastname  \
# 0           1.803991e+11            DIAMOND         UDOIDIONG
# 1           1.403991e+11            KENNETH           ONWORDI
# 2           1.503991e+11          OLUWASEUN            FAYOMI
# 3           3.403993e+11            charles            udogwu
# 4           1.503993e+11              JAMES             ARONI
# ...                  ...                ...               ...
# 12503                NaN                NaN               NaN
# 12504                NaN                NaN               NaN
# 12505                NaN                NaN               NaN
# 12506                NaN                NaN               NaN
# 12507                NaN                NaN               NaN
#
#                  borrower_email  \
# 0       diamondray943@gmail.com
# 1          talk2sirnd@yahoo.com
# 2        fayomiooseun@yahoo.com
# 3                           NaN
# 4      jamesenders007@gmail.com
# ...                         ...
# 12503                       NaN
# 12504                       NaN
# 12505                       NaN
# 12506                       NaN
# 12507                       NaN
#
#                                         borrower_address  mandates_bank  \
# 0       NATIONAL OIL SPILL DETECTION AND RESPONSE AGENCY   1.803991e+11
# 1      FEDERAL MINISTRY OF INFORMATION & CULTURE - HQTRS   1.403991e+11
# 2                  MEDICAL AND DENTAL COUNCIL OF NIGERIA   1.503991e+11
# 3                    FEDERAL MEDICAL CENTRE, EBUTE METTA   3.403993e+11
# 4                    NATIONAL YOUTH SERVICE CORPS (NYSC)   1.503993e+11
# ...                                                  ...            ...
# 12503                                                NaN   3.404668e+11
# 12504                                                NaN   3.503991e+11
# 12505                                                NaN   3.504338e+11
# 12506                                                NaN   3.504404e+11
# 12507                                                NaN   3.504621e+11
#
#          CREDIT  credit_difference
# 0      50000.00               0.00
# 1      29378.93             148.43
# 2      37500.00               0.00
# 3      37500.00               0.00
# 4      12500.00               0.00
# ...         ...                ...
# 12503  13300.00                NaN
# 12504      1.00                NaN
# 12505  11970.00                NaN
# 12506   6650.00                NaN
# 12507   7980.00                NaN
#
# [12508 rows x 17 columns]

# %%
# merged.astype("str").to_csv("result.csv")

# %%
excess_mask = merged["credit_difference"] > 0
less_mask = merged["credit_difference"] < 0
unknowns_mask = merged["loan_id"].isnull()
not_in_bank_mask = merged[" CREDIT"].isnull()

# %%
excess = merged[excess_mask]
less = merged[less_mask]
unknowns = merged[unknowns_mask]
not_in_bank = merged[not_in_bank_mask]

# %%
unknowns
# Out:
#        loan_id  loan_principal_amount loan_released_date  total_amount_due  \
# 12341      NaN                    NaN                NaN               NaN
# 12342      NaN                    NaN                NaN               NaN
# 12343      NaN                    NaN                NaN               NaN
# 12344      NaN                    NaN                NaN               NaN
# 12345      NaN                    NaN                NaN               NaN
# ...        ...                    ...                ...               ...
# 12503      NaN                    NaN                NaN               NaN
# 12504      NaN                    NaN                NaN               NaN
# 12505      NaN                    NaN                NaN               NaN
# 12506      NaN                    NaN                NaN               NaN
# 12507      NaN                    NaN                NaN               NaN
#
#        balance_amount due_date  total_paid  bvn  account_no  \
# 12341             NaN      NaN         NaN  NaN         NaN
# 12342             NaN      NaN         NaN  NaN         NaN
# 12343             NaN      NaN         NaN  NaN         NaN
# 12344             NaN      NaN         NaN  NaN         NaN
# 12345             NaN      NaN         NaN  NaN         NaN
# ...               ...      ...         ...  ...         ...
# 12503             NaN      NaN         NaN  NaN         NaN
# 12504             NaN      NaN         NaN  NaN         NaN
# 12505             NaN      NaN         NaN  NaN         NaN
# 12506             NaN      NaN         NaN  NaN         NaN
# 12507             NaN      NaN         NaN  NaN         NaN
#
#        mandates_loandisk borrower_firstname borrower_lastname borrower_email  \
# 12341                NaN                NaN               NaN            NaN
# 12342                NaN                NaN               NaN            NaN
# 12343                NaN                NaN               NaN            NaN
# 12344                NaN                NaN               NaN            NaN
# 12345                NaN                NaN               NaN            NaN
# ...                  ...                ...               ...            ...
# 12503                NaN                NaN               NaN            NaN
# 12504                NaN                NaN               NaN            NaN
# 12505                NaN                NaN               NaN            NaN
# 12506                NaN                NaN               NaN            NaN
# 12507                NaN                NaN               NaN            NaN
#
#       borrower_address  mandates_bank   CREDIT  credit_difference
# 12341              NaN   1.003983e+11      1.0                NaN
# 12342              NaN   1.003995e+11      1.0                NaN
# 12343              NaN   1.003995e+11      1.0                NaN
# 12344              NaN   1.004370e+11  13300.0                NaN
# 12345              NaN   1.004416e+11   9310.0                NaN
# ...                ...            ...      ...                ...
# 12503              NaN   3.404668e+11  13300.0                NaN
# 12504              NaN   3.503991e+11      1.0                NaN
# 12505              NaN   3.504338e+11  11970.0                NaN
# 12506              NaN   3.504404e+11   6650.0                NaN
# 12507              NaN   3.504621e+11   7980.0                NaN
#
# [167 rows x 17 columns]

# %%
x = merged.groupby("loan_id").filter(lambda x: x["loan_id"] != np.nan)

# %%
with pd.ExcelWriter('result.xlsx') as writer:  
    
    excess.to_excel(writer, sheet_name='excess')
    less.to_excel(writer, sheet_name='less')
    unknowns.to_excel(writer, sheet_name='unknowns')
    not_in_bank.to_excel(writer, sheet_name='not_in_bank')

# %%
mandates_n_creds = mandates_n_creds.round(2)
loan_disk = loan_disk.round(2)

mandates_n_creds.drop(["Unnamed: 0"], axis = 1, inplace = True) # drop the unwanted column Unnamed: 0 from mandates

mandates_n_creds.columns = ['mandates_bank', ' CREDIT'] # rename mandates to mandates_bank

required_columns = ['loan_id',
                     'loan_principal_amount',
                     'loan_released_date',
                     'total_amount_due',
                     'balance_amount',
                     'due_date',
                     'total_paid',
                     'custom_field_4361',
                     'custom_field_4178',
                     'custom_field_5262',
                     'borrower_firstname',
                     'borrower_lastname',
                     'borrower_email',
                     'borrower_address',
                     ]
loan_disk_target = loan_disk[required_columns]

required_columns_customized = ['loan_id',
                                 'loan_principal_amount',
                                 'loan_released_date',
                                 'total_amount_due',
                                 'balance_amount',
                                 'due_date',
                                 'total_paid',
                                 'bvn',
                                 'account_no',
                                 'mandates_loandisk',
                                 'borrower_firstname',
                                 'borrower_lastname',
                                 'borrower_email',
                                 'borrower_address',
                                 ]

loan_disk_target.columns = required_columns_customized # change  certain column names in the fields

merged = pd.merge(
                 left = loan_disk_target, 
                 right=mandates_n_creds, 
                 how="outer", 
                 left_on="mandates_loandisk", 
                 right_on="mandates_bank"
                 )

credit_difference = merged.total_paid - merged[" CREDIT"]
merged["credit_difference"] = credit_difference

excess_mask = merged["credit_difference"] > 0
less_mask = merged["credit_difference"] < 0
unknowns_mask = merged["loan_id"].isnull()
not_in_bank_mask = merged[" CREDIT"].isnull()

excess = merged[excess_mask]
less = merged[less_mask]
unknowns = merged[unknowns_mask]
not_in_bank = merged[not_in_bank_mask]

with pd.ExcelWriter('result.xlsx') as writer:  
    
    excess.to_excel(writer, sheet_name='excess')
    less.to_excel(writer, sheet_name='less')
    unknowns.to_excel(writer, sheet_name='unknowns')
    not_in_bank.to_excel(writer, sheet_name='not_in_bank')
