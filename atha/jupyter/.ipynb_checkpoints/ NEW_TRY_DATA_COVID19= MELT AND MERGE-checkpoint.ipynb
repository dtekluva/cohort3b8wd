# %%
import pandas as pd

# %%
# cases="https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_confirmed_global.csv&filename=time_series_covid19_confirmed_global.csv"
# deaths="https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_deaths_global.csv&filename=time_series_covid19_deaths_global.csv"
# recoveries="https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_recovered_global.csv&filename=time_series_covid19_recovered_global.csv"

# %%
data_cases=pd.read_csv(cases)
data_death=pd.read_csv(death)
data_recoveries=pd.read_csv(recoveries)

# %%
data_cases.to_csv("covidcases.csv")
data_death.to_csv("coviddeath.csv")
data_recoveries.to_csv("covidrecoveries.csv")

# %%
cases="covidcases.csv"
death="coviddeath.csv"
recoveries="covidrecoveries.csv"

# %%
cases
# Out:
# 'https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_confirmed_global.csv&filename=time_series_covid19_confirmed_global.csv'

# %%
data_cases

# %%
data_death
# Out:
#     Province/State      Country/Region        Lat        Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110   67.709953        0
# 1              NaN             Albania  41.153300   20.168300        0
# 2              NaN             Algeria  28.033900    1.659600        0
# 3              NaN             Andorra  42.506300    1.521800        0
# 4              NaN              Angola -11.202700   17.873900        0
# ..             ...                 ...        ...         ...      ...
# 269            NaN             Vietnam  14.058324  108.277199        0
# 270            NaN  West Bank and Gaza  31.952200   35.233200        0
# 271            NaN               Yemen  15.552727   48.516388        0
# 272            NaN              Zambia -13.133897   27.849332        0
# 273            NaN            Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  3/21/21  3/22/21  \
# ...

# %%
data_recoveries
# Out:
#     Province/State      Country/Region        Lat        Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110   67.709953        0
# 1              NaN             Albania  41.153300   20.168300        0
# 2              NaN             Algeria  28.033900    1.659600        0
# 3              NaN             Andorra  42.506300    1.521800        0
# 4              NaN              Angola -11.202700   17.873900        0
# ..             ...                 ...        ...         ...      ...
# 254            NaN             Vietnam  14.058324  108.277199        0
# 255            NaN  West Bank and Gaza  31.952200   35.233200        0
# 256            NaN               Yemen  15.552727   48.516388        0
# 257            NaN              Zambia -13.133897   27.849332        0
# 258            NaN            Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  3/21/21  3/22/21  \
# ...

# %%
data_cases.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '3/21/21', '3/22/21', '3/23/21', '3/24/21', '3/25/21', '3/26/21',
#        '3/27/21', '3/28/21', '3/29/21', '3/30/21'],
#       dtype='object', length=438)

# %%
data_cases.drop(['Province/State', 'Lat', 'Long'], axis = 1, inplace=True)

# %%
data_cases
# Out:
#          Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0           Afghanistan        0        0        0        0        0        0
# 1               Albania        0        0        0        0        0        0
# 2               Algeria        0        0        0        0        0        0
# 3               Andorra        0        0        0        0        0        0
# 4                Angola        0        0        0        0        0        0
# ..                  ...      ...      ...      ...      ...      ...      ...
# 269             Vietnam        0        2        2        2        2        2
# 270  West Bank and Gaza        0        0        0        0        0        0
# 271               Yemen        0        0        0        0        0        0
# 272              Zambia        0        0        0        0        0        0
# 273            Zimbabwe        0        0        0        0        0        0
#
# ...

# %%
melted_data_cases = data_cases.melt(id_vars=['Country/Region'], value_name='cases', var_name='dates') #melting

# %%
melted_data_cases
# Out:
#             Country/Region    dates   cases
# 0              Afghanistan  1/22/20       0
# 1                  Albania  1/22/20       0
# 2                  Algeria  1/22/20       0
# 3                  Andorra  1/22/20       0
# 4                   Angola  1/22/20       0
# ...                    ...      ...     ...
# 118911             Vietnam  3/30/21    2594
# 118912  West Bank and Gaza  3/30/21  240065
# 118913               Yemen  3/30/21    4247
# 118914              Zambia  3/30/21   88199
# 118915            Zimbabwe  3/30/21   36839
#
# [118916 rows x 3 columns]

# %%
data_cases.iloc[:1]
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    Afghanistan        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  3/21/21  3/22/21  3/23/21  3/24/21  \
# 0        0        0        0  ...    56103    56153    56177    56192
#
#    3/25/21  3/26/21  3/27/21  3/28/21  3/29/21  3/30/21
# 0    56226    56254    56290    56294    56322    56384
#
# [1 rows x 435 columns]

# %%
data_cases.iloc[:6] #checking for loaction of fields using index location
# Out:
#         Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0          Afghanistan        0        0        0        0        0        0
# 1              Albania        0        0        0        0        0        0
# 2              Algeria        0        0        0        0        0        0
# 3              Andorra        0        0        0        0        0        0
# 4               Angola        0        0        0        0        0        0
# 5  Antigua and Barbuda        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  3/21/21  3/22/21  3/23/21  3/24/21  \
# 0        0        0        0  ...    56103    56153    56177    56192
# 1        0        0        0  ...   121200   121544   121847   122295
# 2        0        0        0  ...   116157   116255   116349   116438
# 3        0        0        0  ...    11517    11545    11591    11638
# 4        0        0        0  ...    21733    21757    21774    21836
# ...

# %%
melted_data_cases[melted_data_cases["Country/Region"] == "Afghanistan"] #targetting all cases of afganistan
# Out:
#        Country/Region    dates  cases
# 0         Afghanistan  1/22/20      0
# 274       Afghanistan  1/23/20      0
# 548       Afghanistan  1/24/20      0
# 822       Afghanistan  1/25/20      0
# 1096      Afghanistan  1/26/20      0
# ...               ...      ...    ...
# 117546    Afghanistan  3/26/21  56254
# 117820    Afghanistan  3/27/21  56290
# 118094    Afghanistan  3/28/21  56294
# 118368    Afghanistan  3/29/21  56322
# 118642    Afghanistan  3/30/21  56384
#
# [434 rows x 3 columns]

# %%
data_death.drop(['Province/State', 'Lat', 'Long'], axis = 1, inplace=True) #dropping the unused columns

# %%
melted_data_death = data_death.melt(id_vars=['Country/Region'], value_name='deaths', var_name='dates')

# %%
melted_data_death
# Out:
#             Country/Region    dates  deaths
# 0              Afghanistan  1/22/20       0
# 1                  Albania  1/22/20       0
# 2                  Algeria  1/22/20       0
# 3                  Andorra  1/22/20       0
# 4                   Angola  1/22/20       0
# ...                    ...      ...     ...
# 118911             Vietnam  3/30/21      35
# 118912  West Bank and Gaza  3/30/21    2614
# 118913               Yemen  3/30/21     882
# 118914              Zambia  3/30/21    1202
# 118915            Zimbabwe  3/30/21    1520
#
# [118916 rows x 3 columns]

# %%
melted_data_cases["deaths"]=melted_data_death.deaths

# %%
melted_data_cases
# Out:
#             Country/Region    dates   cases  deaths
# 0              Afghanistan  1/22/20       0       0
# 1                  Albania  1/22/20       0       0
# 2                  Algeria  1/22/20       0       0
# 3                  Andorra  1/22/20       0       0
# 4                   Angola  1/22/20       0       0
# ...                    ...      ...     ...     ...
# 118911             Vietnam  3/30/21    2594      35
# 118912  West Bank and Gaza  3/30/21  240065    2614
# 118913               Yemen  3/30/21    4247     882
# 118914              Zambia  3/30/21   88199    1202
# 118915            Zimbabwe  3/30/21   36839    1520
#
# [118916 rows x 4 columns]

# %%
melted_data_cases
# Out:
#             Country/Region    dates   cases  deaths
# 0              Afghanistan  1/22/20       0       0
# 1                  Albania  1/22/20       0       0
# 2                  Algeria  1/22/20       0       0
# 3                  Andorra  1/22/20       0       0
# 4                   Angola  1/22/20       0       0
# ...                    ...      ...     ...     ...
# 118911             Vietnam  3/30/21    2594      35
# 118912  West Bank and Gaza  3/30/21  240065    2614
# 118913               Yemen  3/30/21    4247     882
# 118914              Zambia  3/30/21   88199    1202
# 118915            Zimbabwe  3/30/21   36839    1520
#
# [118916 rows x 4 columns]

# %%
melted_data_cases["Country/Region"]
# Out:
# 0                Afghanistan
# 1                    Albania
# 2                    Algeria
# 3                    Andorra
# 4                     Angola
#                  ...
# 118911               Vietnam
# 118912    West Bank and Gaza
# 118913                 Yemen
# 118914                Zambia
# 118915              Zimbabwe
# Name: Country/Region, Length: 118916, dtype: object

# %%
 melted_data_cases.count()
# Out:
# Country/Region    118916
# dates             118916
# cases             118916
# deaths            118916
# dtype: int64

# %%
death_average=melted_data_cases["deaths"].mean()

# %%
cases_average=melted_data_cases["cases"].mean()

# %%
data_cases.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '3/21/21', '3/22/21', '3/23/21', '3/24/21', '3/25/21', '3/26/21',
#        '3/27/21', '3/28/21', '3/29/21', '3/30/21'],
#       dtype='object', length=438)

# %%
death_average
# Out:
# 3647.6597093746846

# %%
cases_average
# Out:
# 144927.2048757106

# %%
melted_data_cases
# Out:
#             Country/Region    dates   cases  deaths
# 0              Afghanistan  1/22/20       0       0
# 1                  Albania  1/22/20       0       0
# 2                  Algeria  1/22/20       0       0
# 3                  Andorra  1/22/20       0       0
# 4                   Angola  1/22/20       0       0
# ...                    ...      ...     ...     ...
# 118911             Vietnam  3/30/21    2594      35
# 118912  West Bank and Gaza  3/30/21  240065    2614
# 118913               Yemen  3/30/21    4247     882
# 118914              Zambia  3/30/21   88199    1202
# 118915            Zimbabwe  3/30/21   36839    1520
#
# [118916 rows x 4 columns]

# %%
melted_data_recoveries = data_death.melt(id_vars=['Country/Region'], value_name='recoveries', var_name='dates')

# %%
melted_data_recoveries
# Out:
#             Country/Region           dates recoveries
# 0              Afghanistan  Province/State        NaN
# 1                  Albania  Province/State        NaN
# 2                  Algeria  Province/State        NaN
# 3                  Andorra  Province/State        NaN
# 4                   Angola  Province/State        NaN
# ...                    ...             ...        ...
# 119733             Vietnam         3/30/21         35
# 119734  West Bank and Gaza         3/30/21       2614
# 119735               Yemen         3/30/21        882
# 119736              Zambia         3/30/21       1202
# 119737            Zimbabwe         3/30/21       1520
#
# [119738 rows x 3 columns]

# %%
melted_data_cases["recoveries"]=melted_data_recoveries.recoveries

# %%
melted_data_cases
# Out:
#             Country/Region    dates   cases  deaths recoveries
# 0              Afghanistan  1/22/20       0       0        NaN
# 1                  Albania  1/22/20       0       0        NaN
# 2                  Algeria  1/22/20       0       0        NaN
# 3                  Andorra  1/22/20       0       0        NaN
# 4                   Angola  1/22/20       0       0        NaN
# ...                    ...      ...     ...     ...        ...
# 118911             Vietnam  3/30/21    2594      35         35
# 118912  West Bank and Gaza  3/30/21  240065    2614       2557
# 118913               Yemen  3/30/21    4247     882        832
# 118914              Zambia  3/30/21   88199    1202       1198
# 118915            Zimbabwe  3/30/21   36839    1520       1519
#
# [118916 rows x 5 columns]

# %%
melted_data_cases.drop(['recoveries'], axis = 1, inplace=True)

# %%
melted_data_cases
# Out:
#             Country/Region    dates   cases  deaths
# 0              Afghanistan  1/22/20       0       0
# 1                  Albania  1/22/20       0       0
# 2                  Algeria  1/22/20       0       0
# 3                  Andorra  1/22/20       0       0
# 4                   Angola  1/22/20       0       0
# ...                    ...      ...     ...     ...
# 118911             Vietnam  3/30/21    2594      35
# 118912  West Bank and Gaza  3/30/21  240065    2614
# 118913               Yemen  3/30/21    4247     882
# 118914              Zambia  3/30/21   88199    1202
# 118915            Zimbabwe  3/30/21   36839    1520
#
# [118916 rows x 4 columns]

# %%
melted_data_recoveries
# Out:
#             Country/Region           dates recoveries
# 0              Afghanistan  Province/State        NaN
# 1                  Albania  Province/State        NaN
# 2                  Algeria  Province/State        NaN
# 3                  Andorra  Province/State        NaN
# 4                   Angola  Province/State        NaN
# ...                    ...             ...        ...
# 119733             Vietnam         3/30/21         35
# 119734  West Bank and Gaza         3/30/21       2614
# 119735               Yemen         3/30/21        882
# 119736              Zambia         3/30/21       1202
# 119737            Zimbabwe         3/30/21       1520
#
# [119738 rows x 3 columns]

# %%
melted_data_cases
# Out:
#             Country/Region    dates   cases  deaths
# 0              Afghanistan  1/22/20       0       0
# 1                  Albania  1/22/20       0       0
# 2                  Algeria  1/22/20       0       0
# 3                  Andorra  1/22/20       0       0
# 4                   Angola  1/22/20       0       0
# ...                    ...      ...     ...     ...
# 118911             Vietnam  3/30/21    2594      35
# 118912  West Bank and Gaza  3/30/21  240065    2614
# 118913               Yemen  3/30/21    4247     882
# 118914              Zambia  3/30/21   88199    1202
# 118915            Zimbabwe  3/30/21   36839    1520
#
# [118916 rows x 4 columns]

# %%
grouped_data=melted_data_cases.groupby("Country/Region").max().reset_index()

# %%
grouped_data
# Out:
#          Country/Region   dates   cases  deaths
# 0           Afghanistan  9/9/20   56384    2476
# 1               Albania  9/9/20  124723    2227
# 2               Algeria  9/9/20  117061    3089
# 3               Andorra  9/9/20   11944     115
# 4                Angola  9/9/20   22182     536
# ..                  ...     ...     ...     ...
# 187             Vietnam  9/9/20    2594      35
# 188  West Bank and Gaza  9/9/20  240065    2614
# 189               Yemen  9/9/20    4247     882
# 190              Zambia  9/9/20   88199    1202
# 191            Zimbabwe  9/9/20   36839    1520
#
# [192 rows x 4 columns]

# %%
target_country = input("what country would you like to see? : ")
target_country_mask=grouped_data["Country/Region"]==target_country
grouped_data[target_country_mask]
# Out:
# what country would you like to see? : Nigeria
#     Country/Region   dates   cases  deaths
# 128        Nigeria  9/9/20  162762    2056

# %%
melted_data_cases[melted_data_cases["Country/Region"]=="Afghanistan"]["cases"].diff()
# Out:
# 0          NaN
# 274        0.0
# 548        0.0
# 822        0.0
# 1096       0.0
#           ...
# 117546    28.0
# 117820    36.0
# 118094     4.0
# 118368    28.0
# 118642    62.0
# Name: cases, Length: 434, dtype: float64

# %%
rolling_diff_cases=melted_data_cases[melted_data_cases["Country/Region"]=="Nigeria"]["cases"].diff()

# %%
average_cases=rolling_diff_cases.max()

# %%
average_cases
# Out:
# 2464.0
